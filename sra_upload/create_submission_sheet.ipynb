# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from barcode_runs.csv
# Here are the first few entries in the Illumina runs:
#      date  virus_batch library sample_type  antibody  antibody_concentration  \
# 0  221027            1    libA    antibody  AUSAB-13                0.007520
# 1  221027            1    libA    antibody  AUSAB-13                0.005013
# 2  221027            1    libA    antibody  AUSAB-13                0.003342
# 3  221027            1    libA    antibody  AUSAB-13                0.002228
# 4  221027            1    libA    antibody  AUSAB-13                0.001485
#
#    replicate  \
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
#                                                                                                                       fastq_R1  \
# 0     /fh/fast/bloom_j/SR/ngs/illumina/fwelsh/221027_VH01189_20_AAC7KHTM5/Unaligned/Project_fwelsh/ser13_4x_S7_R1_001.fastq.gz
# 1   /fh/fast/bloom_j/SR/ngs/illumina/fwelsh/221027_VH01189_20_AAC7KHTM5/Unaligned/Project_fwelsh/ser13_2-6x_S8_R1_001.fastq.gz
# 2   /fh/fast/bloom_j/SR/ngs/illumina/fwelsh/221027_VH01189_20_AAC7KHTM5/Unaligned/Project_fwelsh/ser13_1-7x_S9_R1_001.fastq.gz
# 3  /fh/fast/bloom_j/SR/ngs/illumina/fwelsh/221027_VH01189_20_AAC7KHTM5/Unaligned/Project_fwelsh/ser13_1-2x_S10_R1_001.fastq.gz
# 4  /fh/fast/bloom_j/SR/ngs/illumina/fwelsh/221027_VH01189_20_AAC7KHTM5/Unaligned/Project_fwelsh/ser13_0-8x_S11_R1_001.fastq.gz
#
#   exclude_after_counts notes neut_standard_name
# 0                  NaN   NaN                 H6
# 1                  NaN   NaN                 H6
# 2                  NaN   NaN                 H6
# 3                  NaN   NaN                 H6
# 4                  NaN   NaN                 H6

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['antibody'],
        title=lambda x: 'HongKong/2019 mutational antig Illumina barcode sequencing for ' + x['antibody'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['fastq_R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 submissions_tidy = (
# ----> 2     illumina_runs
#       3     .assign(
#       4         biosample_accession=lambda x: config['biosample_accession'],
#       5         library_ID=lambda x: x['library'] + '_' + x['antibody'],
#       6         title=lambda x: 'HongKong/2019 mutational antig Illumina barcode sequencing for ' + x['antibody'],
#       7         library_strategy='AMPLICON',
#       8         library_source='SYNTHETIC',
#       9         library_selection='PCR',
#      10         library_layout='single',
#      11         platform='ILLUMINA',
#      12         instrument_model='Illumina HiSeq 2500',
#      13         design_description='PCR of barcodes from RBD variants',
#      14         filetype='fastq',
#      15         filename_fullpath=lambda x: x['fastq_R1'].str.split(';')
#      16                                     .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(str(f)) for f in flist))),
#      17         )
#      18     .explode('filename_fullpath')
#      19     .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
#      20             filename=lambda x: x['filename_fullpath'].map(os.path.basename))
#      21     .drop(columns=illumina_runs.columns)
#      22     .reset_index(drop=True)
#      23     )
#      25 assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()
#      27 print('Here are the first few submission entries in tidy format:')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:5239, in DataFrame.assign(self, **kwargs)
#    5236 data = self.copy(deep=None)
#    5238 for k, v in kwargs.items():
# -> 5239     data[k] = com.apply_if_callable(v, data)
#    5240 return data
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/common.py:384, in apply_if_callable(maybe_callable, obj, **kwargs)
#     373 """
#     374 Evaluate possibly callable input using obj and kwargs if it is callable,
#     375 otherwise return as it is.
#    (...)
#     381 **kwargs
#     382 """
#     383 if callable(maybe_callable):
# --> 384     return maybe_callable(obj, **kwargs)
#     386 return maybe_callable
#
# Cell In[24], line 20, in <lambda>(x)
#       1 submissions_tidy = (
#       2     illumina_runs
#       3     .assign(
#       4         biosample_accession=lambda x: config['biosample_accession'],
#       5         library_ID=lambda x: x['library'] + '_' + x['antibody'],
#       6         title=lambda x: 'HongKong/2019 mutational antig Illumina barcode sequencing for ' + x['antibody'],
#       7         library_strategy='AMPLICON',
#       8         library_source='SYNTHETIC',
#       9         library_selection='PCR',
#      10         library_layout='single',
#      11         platform='ILLUMINA',
#      12         instrument_model='Illumina HiSeq 2500',
#      13         design_description='PCR of barcodes from RBD variants',
#      14         filetype='fastq',
#      15         filename_fullpath=lambda x: x['fastq_R1'].str.split(';')
#      16                                     .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(str(f)) for f in flist))),
#      17         )
#      18     .explode('filename_fullpath')
#      19     .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
# ---> 20             filename=lambda x: x['filename_fullpath'].map(os.path.basename))
#      21     .drop(columns=illumina_runs.columns)
#      22     .reset_index(drop=True)
#      23     )
#      25 assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()
#      27 print('Here are the first few submission entries in tidy format:')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/opt/miniconda3/lib/python3.9/posixpath.py:142, in basename(p)
#     140 def basename(p):
#     141     """Returns the final component of a pathname"""
# --> 142     p = os.fspath(p)
#     143     sep = _get_sep(p)
#     144     i = p.rfind(sep) + 1
#
# TypeError: expected str, bytes or os.PathLike object, not float

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#    biosample_accession                        library_ID  n_files
# 0         SAMN18148595    lib2_expt_64-COV-107-80-escape        2
# 1         SAMN18148595      lib1_expt_53-C135-400-escape        1
# 2         SAMN18148595   lib2_expt_63-COV-072-200-escape        1
# 3         SAMN18148595    lib2_expt_62-COV-057-50-escape        1
# 4         SAMN18148595   lib2_expt_61-COV-047-200-escape        1
# 5         SAMN18148595   lib2_expt_60-COV-021-500-escape        1
# 6         SAMN18148595  lib2_expt_60-64-none-0-reference        1
# 7         SAMN18148595      lib2_expt_58-C002-400-escape        1
# 8         SAMN18148595      lib2_expt_57-C105-400-escape        1
# 9         SAMN18148595      lib2_expt_56-C110-400-escape        1
# 10        SAMN18148595      lib2_expt_55-C121-400-escape        1
# 11        SAMN18148595      lib2_expt_54-C144-400-escape        1
# 12        SAMN18148595      lib2_expt_53-C135-400-escape        1
# 13        SAMN18148595  lib1_expt_53-59-none-0-reference        1
# 14        SAMN18148595    lib1_expt_64-COV-107-80-escape        1
# 15        SAMN18148595   lib1_expt_63-COV-072-200-escape        1
# 16        SAMN18148595    lib1_expt_62-COV-057-50-escape        1
# 17        SAMN18148595   lib1_expt_61-COV-047-200-escape        1
# 18        SAMN18148595   lib1_expt_60-COV-021-500-escape        1
# 19        SAMN18148595  lib1_expt_60-64-none-0-reference        1
# 20        SAMN18148595      lib1_expt_58-C002-400-escape        1
# 21        SAMN18148595      lib1_expt_57-C105-400-escape        1
# 22        SAMN18148595      lib1_expt_56-C110-400-escape        1
# 23        SAMN18148595      lib1_expt_55-C121-400-escape        1
# 24        SAMN18148595      lib1_expt_54-C144-400-escape        1
# 25        SAMN18148595  lib2_expt_53-59-none-0-reference        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                        library_ID  \
# 0        SAMN18148595  lib1_expt_53-59-none-0-reference
# 1        SAMN18148595  lib2_expt_53-59-none-0-reference
# 2        SAMN18148595  lib1_expt_60-64-none-0-reference
# 3        SAMN18148595  lib2_expt_60-64-none-0-reference
# 4        SAMN18148595      lib1_expt_58-C002-400-escape
#
#                                                                                          title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_53-59-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_53-59-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_60-64-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_60-64-none-0-reference
# 4      SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_58-C002-400-escape
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                        filename filename2
# 0  expt_53-59_lib1_ref_S16_L002_R1_001.fastq.gz       NaN
# 1  expt_53-59_lib2_ref_S17_L002_R1_001.fastq.gz       NaN
# 2  expt_60-64_lib1_ref_S29_L002_R1_001.fastq.gz       NaN
# 3  expt_60-64_lib2_ref_S30_L002_R1_001.fastq.gz       NaN
# 4   expt_58_lib1_abneg_S11_L002_R1_001.fastq.gz       NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
