# %%
import pandas as pd
import os
import yaml

# %%
os.chdir('../')

with open("config.yaml") as f:
    config = yaml.safe_load(f)

# %%
bc_runs = pd.read_csv('data/barcode_runs.csv')
bc_runs
# Out:
#        date  virus_batch library          sample_type antibody  \
# 0    220121            1    libA       no-VEP_control      NaN
# 1    220121            1    libA       no-VEP_control      NaN
# 2    220121            1    libA       no-VEP_control      NaN
# 3    220121            1    libA       no-VEP_control      NaN
# 4    220121            1    libA       no-VEP_control      NaN
# ..      ...          ...     ...                  ...      ...
# 110  220711            1    libB  no-antibody_control      NaN
# 111  220711            1    libA       no-VEP_control      NaN
# 112  220711            1    libA       no-VEP_control      NaN
# 113  220711            1    libB       no-VEP_control      NaN
# 114  220711            1    libB       no-VEP_control      NaN
#
#      antibody_concentration    replicate  \
# 0                       NaN        25x_1
# 1                       NaN        25x_2
# 2                       NaN   25x_2_RT-2
# ...

# %%
bc_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    115 non-null    int64
#  1   virus_batch             115 non-null    int64
#  2   library                 115 non-null    object
#  3   sample_type             115 non-null    object
#  4   antibody                52 non-null     object
#  5   antibody_concentration  52 non-null     float64
#  6   replicate               115 non-null    object
#  7   fastq_R1                115 non-null    object
#  8   exclude_after_counts    64 non-null     object
#  9   notes                   48 non-null     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 9.1+ KB

# %%
ausab07_conc_conversion = {
    0.00158: 0.00079,
    0.00632: 0.00316,
    0.0158: 0.00790,
    0.0395: 0.0198,
    0.079: 0.0395
}

ausab13_conc_conversion = {
    0.0003675: 0.00018,
    0.00147: 0.000737,
    0.00588: 0.00294,
    0.0147: 0.00735,
    0.03675: 0.0184
}

# %%
ser_conc_conversion = {
    # ausab07 values
    0.00158: 0.00079,
    0.00632: 0.00316,
    0.0158: 0.00790,
    0.0395: 0.0198,
    0.079: 0.0395,
    # ausab13 values
    0.0003675: 0.00018,
    0.00147: 0.000737,
    0.00588: 0.00294,
    0.0147: 0.00735,
    0.03675: 0.0184
}

# %%
bc_runs_updated = bc_runs.replace({'antibody_concentration': ausab07_conc_conversion})
bc_runs_updated = bc_runs.replace({'antibody_concentration': ausab13_conc_conversion})

# %%
bc_runs_updated.to_csv('data/barcode_runs.csv', index=False)
