# %% [markdown]
# # Screening pediatric sera for neutralizing activity against HK/19

# %%
import pandas as pd

import neutcurve
from neutcurve.colorschemes import CBMARKERS, CBPALETTE

import matplotlib
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
neut_data_run1 = pd.read_csv('neut_data/230208_neuts_tidy.csv')

# %%
# fit with neutcurve package
fits = neutcurve.CurveFits(neut_data_run1)

# %%
fig, axes = fits.plotSera(ncol=5,
                          xlabel='serum dilution',
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 13]])
# plt.savefig('figures/230208_ped-sera-neuts_v1.pdf', bbox_inches=bbox)

# %%
neut_data_pbs = pd.read_csv('neut_data/230208_neuts_tidy_PBS.csv')

neut_data_pbs['serum'] =neut_data_pbs['serum'].astype(object)

# %%
# fit with neutcurve package
fits = neutcurve.CurveFits(neut_data_pbs, fixtop=False, fixbottom=False)

# %%
fig, axes = fits.plotSera(ncol=5,
                          xlabel='serum dilution',
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 11]])
# plt.savefig('figures/230208_ped-sera-neuts_media-wash.pdf', bbox_inches=bbox)

# %%
neut_data_run2 = pd.read_csv('neut_data/230210_neuts_tidy.csv')

# fit with neutcurve package
fits = neutcurve.CurveFits(neut_data_run2)

# %%
fig, axes = fits.plotSera(ncol=5,
                          xlabel='serum dilution',
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 13]])
# plt.savefig('figures/230210_ped-sera-neuts.pdf', bbox_inches=bbox)

# %%
neut_data_run2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   serum                 168 non-null    object
#  1   virus                 168 non-null    object
#  2   replicate             168 non-null    int64
#  3   concentration         168 non-null    float64
#  4   fraction infectivity  168 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 6.7+ KB

# %%
full_runs = pd.concat([neut_data_pbs, neut_data_run2])
neut_hits_list = [2323, 2324, 2325, 2354, 2367, 2368, 2369, 2383, '2388', '2389', 
                  '2462', '2463', '3938', '3944', 
                  '3972', '3973', '3975']

neut_hits = full_runs[full_runs['serum'].isin(neut_hits_list)]
neut_hits
# Out:
#     serum virus  replicate  concentration  fraction infectivity
# 32   2323  HK19          1       0.050000              0.189758
# 33   2323  HK19          1       0.025000              0.206016
# 34   2323  HK19          1       0.012500              0.180577
# 35   2323  HK19          1       0.006250              0.176743
# 36   2323  HK19          1       0.003125              0.162464
# ..    ...   ...        ...            ...                   ...
# 147  3975  HK19          1       0.006250              0.706487
# 148  3975  HK19          1       0.003125              0.975298
# 149  3975  HK19          1       0.001563              1.048375
# 150  3975  HK19          1       0.000781              1.038673
# 151  3975  HK19          1       0.000391              1.056406
#
# [136 rows x 5 columns]

# %%
fits = neutcurve.CurveFits(neut_hits)

# %%
fig, axes = fits.plotSera(ncol=5,
                          xlabel='serum dilution',
                          virus_to_color_marker={
                              'HK19': ('green', 'o')
                          },
                          sharex = True
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 11]])
plt.savefig('figures/230210_ped-sera_hits.pdf', bbox_inches=bbox)

# %%
neut_data_final_1 = pd.read_csv('neut_data/230212_neuts_tidy.csv')

# %%
neut_data_final_2 = pd.read_csv('neut_data/230214_neuts_tidy.csv')

# %%
neut_data_final = pd.concat([neut_data_final_1, neut_data_final_2])

# %%
# fit with neutcurve package
fits = neutcurve.CurveFits(neut_data_final)

# %%
fig, axes = fits.plotSera(ncol=5,
                          virus_to_color_marker={
                              'HK19': ('orange', 'o'),
                              'H6': ('gray', 'o')
                          },
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 11]])
plt.savefig('figures/230214_ped-sera-neuts_final.pdf', bbox_inches=bbox)

# %%
neuts_final_selections = neut_data_final.loc[(neut_data_final['serum'] == 2367) |
                                         (neut_data_final['serum'] == 3944) |
                                         (neut_data_final['serum'] == 2462) |
                                         (neut_data_final['serum'] == 2389) |
                                         (neut_data_final['serum'] == 2323)]

# %%
fits_final = neutcurve.CurveFits(neuts_final_selections)

fig, axes = fits_final.plotSera(ncol=3,
                          virus_to_color_marker={
                              'HK19': ('orange', 'o'),
                              'H6': ('gray', 'o')
                          },
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [11, 6]])
plt.savefig('figures/230214_ped-sera-neuts_most-potent.pdf', bbox_inches=bbox)

# %%
serum_ic99 = fits.fitParams(ics=[99])
serum_ic99.sort_values('ic99')
# Out:
#     serum virus replicate  nreplicates      ic99    ic99_bound ic99_str  \
# 20   2367  HK19   average            2  0.001086  interpolated  0.00109
# 8    3944  HK19   average            2  0.002136  interpolated  0.00214
# 4    2462  HK19   average            2  0.016364  interpolated   0.0164
# 2    2389  HK19   average            2  0.018311  interpolated   0.0183
# 14   2323  HK19   average            2  0.022235  interpolated   0.0222
# 0    2388  HK19   average            2  0.025378  interpolated   0.0254
# 5    2463  HK19   average            2  0.031925  interpolated   0.0319
# 12   3973    H6   average            2  0.041715  interpolated   0.0417
# 17   2325  HK19   average            2  0.050000         lower    >0.05
# 6    3938  HK19   average            2  0.064815  interpolated   0.0648
# 22   2368  HK19   average            2  0.100000         lower     >0.1
# 19   2354  HK19   average            2  0.100000         lower     >0.1
# 13   3975  HK19   average            2  0.100000         lower     >0.1
# 16   2324  HK19   average            2  0.100000         lower     >0.1
# 11   3973  HK19   average            2  0.100000         lower     >0.1
# 10   3972  HK19   average            2  0.100000         lower     >0.1
# 23   2369  HK19   average            2  0.100000         lower     >0.1
# 24   2383  HK19   average            2  0.100000         lower     >0.1
# 3    2389    H6   average            2  0.125000         lower   >0.125
# 15   2323    H6   average            2  0.125000         lower   >0.125
# 7    3938    H6   average            2  0.125000         lower   >0.125
# 18   2325    H6   average            2  0.125000         lower   >0.125
# 1    2388    H6   average            2  0.125000         lower   >0.125
# 21   2367    H6   average            2  0.125000         lower   >0.125
# 9    3944    H6   average            2  0.125000         lower   >0.125
#
#         midpoint      slope  top  bottom
# 20  6.000133e-05   1.586662    1       0
# 8   1.543605e-04   1.748936    1       0
# 4   1.266453e-03   1.795750    1       0
# 2   1.676405e-03   1.921978    1       0
# 14  1.021694e-03   1.491825    1       0
# 0   1.914663e-03   1.778067    1       0
# 5   2.381352e-03   1.770261    1       0
# 12  8.372986e-02  -6.595210    1       0
# 17  4.909473e-03   1.435841    1       0
# 6   5.550385e-03   1.869706    1       0
# 22  1.391457e-02   1.394396    1       0
# 19  7.704800e-03   0.785518    1       0
# 13  4.850509e-03   1.344756    1       0
# 16  6.178653e-03   1.301577    1       0
# 11  4.297629e-03   1.307293    1       0
# 10  8.393884e-03   1.548516    1       0
# 23  1.037422e-02   1.306940    1       0
# 24  2.478794e-02   1.149059    1       0
# 3   2.330065e-04   0.053362    1       0
# 15  2.749094e+00  25.772397    1       0
# 7   3.267248e-05   0.097208    1       0
# 18  1.363990e-03   0.206730    1       0
# 1   1.115405e-03   0.178471    1       0
# 21  1.753633e-03   0.169588    1       0
# 9   1.367947e-33   0.002641    1       0

# %%
neut_data_top5 = pd.read_csv('neut_data/230215_final-neuts_tidy.csv')

fits_top5 = neutcurve.CurveFits(neut_data_top5)

# %%
fig, axes = fits_top5.plotSera(ncol=3,
#                           virus_to_color_marker={
#                               'HK19': ('orange', 'o'),
#                               'H6': ('gray', 'o')
#                           },
                          sharex = False
                         )

# bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 11]])
# plt.savefig('figures/230214_ped-sera-neuts_final.pdf', bbox_inches=bbox)

# %%
serum_ic99 = fits_top5.fitParams(ics=[99])
serum_ic99.sort_values('ic99')
# Out:
#    serum virus replicate  nreplicates      ic99    ic99_bound  ic99_str  \
# 4   2367  HK19   average            2  0.000549  interpolated  0.000549
# 2   3944  HK19   average            2  0.002000  interpolated     0.002
# 3   2323  HK19   average            2  0.012500         lower   >0.0125
# 1   2462  HK19   average            2  0.013448  interpolated    0.0134
# 0   2389  HK19   average            2  0.016192  interpolated    0.0162
#
#    midpoint     slope       top  bottom
# 4  0.000079  2.280828  0.852302       0
# 2  0.000158  1.806033  0.986558       0
# 3  0.001161  1.791093  0.937260       0
# 1  0.001334  1.975136  0.969001       0
# 0  0.001744  2.051065  0.975405       0

# %%
serum_ic99 = fits_top5.fitParams(ics=[99])
serum_ic99.sort_values('ic99')
# Out:
#    serum virus replicate  nreplicates      ic99    ic99_bound ic99_str  \
# 4   2367  HK19   average            2  0.001360  interpolated  0.00136
# 2   3944  HK19   average            2  0.002136  interpolated  0.00214
# 3   2323  HK19   average            2  0.012500         lower  >0.0125
# 1   2462  HK19   average            2  0.016202  interpolated   0.0162
# 0   2389  HK19   average            2  0.018183  interpolated   0.0182
#
#    midpoint     slope  top  bottom
# 4  0.000058  1.460079    1       0
# 2  0.000154  1.749001    1       0
# 3  0.001023  1.534783    1       0
# 1  0.001266  1.802666    1       0
# 0  0.001676  1.927579    1       0

# %%
neut_data_run3 = pd.read_csv('neut_data/230217_neuts_tidy.csv')

# %%
fits = neutcurve.CurveFits(neut_data_run3)

fig, axes = fits.plotSera(ncol=5,
                          xlabel='serum dilution',
                          sharex = False
                         )

bbox = matplotlib.transforms.Bbox([[0, 0], [17.5, 13]])
plt.savefig('figures/230217_ped-sera-neuts.pdf', bbox_inches=bbox)

# %%
serum_ic99 = fits.fitParams(ics=[99])
serum_ic99.sort_values('ic99')
# Out:
#     serum virus replicate  nreplicates      ic99    ic99_bound ic99_str  \
# 0    3977  HK19   average            1  0.019974  interpolated     0.02
# 8    4299  HK19   average            1  0.036645  interpolated   0.0366
# 15   4500  HK19   average            1  0.045013  interpolated    0.045
# 17   4528  HK19   average            1  0.045015  interpolated    0.045
# 19   4530  HK19   average            1  0.050000         lower    >0.05
# 18   4529  HK19   average            1  0.050000         lower    >0.05
# 16   4502  HK19   average            1  0.050000         lower    >0.05
# 14   4493  HK19   average            1  0.050000         lower    >0.05
# 13   4482  HK19   average            1  0.050000         lower    >0.05
# 12   4480  HK19   average            1  0.050000         lower    >0.05
# 11   4479  HK19   average            1  0.050000         lower    >0.05
# 10   4351  HK19   average            1  0.050000         lower    >0.05
# 9    4350  HK19   average            1  0.050000         lower    >0.05
# 7    4156  HK19   average            1  0.050000         lower    >0.05
# 6    4154  HK19   average            1  0.050000         lower    >0.05
# 5    4136  HK19   average            1  0.050000         lower    >0.05
# 4    4134  HK19   average            1  0.050000         lower    >0.05
# 3    4132  HK19   average            1  0.050000         lower    >0.05
# 2    4115  HK19   average            1  0.050000         lower    >0.05
# 1    4077  HK19   average            1  0.050000         lower    >0.05
# 20   4531  HK19   average            1  0.050000         lower    >0.05
# 21   4532  HK19   average            1  0.050000         lower    >0.05
#
#     midpoint     slope  top  bottom
# 0   0.001696  1.863327    1       0
# 8   0.003869  2.043739    1       0
# 15  0.002359  1.558366    1       0
# 17  0.020568  5.866561    1       0
# 19  0.042211  1.907191    1       0
# 18  0.007734  2.065838    1       0
# 16  0.010528  1.361824    1       0
# 14  0.473468  9.783459    1       0
# 13  0.884671  8.284614    1       0
# 12  0.008497  1.810801    1       0
# 11  0.010089  2.084027    1       0
# 10  0.037493  1.646647    1       0
# 9   0.009216  2.052012    1       0
# 7   0.015511  1.909070    1       0
# 6   0.009074  2.088125    1       0
# 5   0.051475  2.087102    1       0
# 4   0.008837  1.698952    1       0
# 3   0.046904  2.795096    1       0
# 2   0.059247  1.772875    1       0
# 1   0.007669  1.845981    1       0
# 20  0.040124  2.268807    1       0
# 21  0.039414  2.170298    1       0
