# %%
import pandas as pd

# %% [markdown]
# pull dataframe listing all possible mutations, whether they're targeted or not, and with mutation type defined. This was originally generated in `barcoded_h3_dms/mutation_distribution.ipynb`.

# %%
mut_counts_full = pd.read_csv('mut_counts_epitope_labels.csv')
mut_counts_full
# Out:
#          library             sample mutation  mut_count  mutation_type  site  \
# 0      libA_rep1  barcoded variants    Y178S        206  nonsynonymous   178
# 1      libA_rep1  barcoded variants    T179S        195  nonsynonymous   179
# 2      libA_rep1  barcoded variants    T179K        193  nonsynonymous   179
# 3      libA_rep1  barcoded variants    T179R        187  nonsynonymous   179
# 4      libA_rep1  barcoded variants    I211S        162  nonsynonymous   211
# ...          ...                ...      ...        ...            ...   ...
# 45675  libB_rep2  barcoded variants    Y530R          0  nonsynonymous   530
# 45676  libB_rep2  barcoded variants    Y530S          0  nonsynonymous   530
# 45677  libB_rep2  barcoded variants    Y530T          0  nonsynonymous   530
# 45678  libB_rep2  barcoded variants    Y530V          0  nonsynonymous   530
# 45679  libB_rep2  barcoded variants    Y530W          0  nonsynonymous   530
#
#               epitope stripped_mut    targeted
# 0      paired_epitope         178S    targeted
# 1      paired_epitope         179S    targeted
# 2      paired_epitope         179K    targeted
# 3      paired_epitope         179R    targeted
# 4      paired_epitope         211S    targeted
# ...               ...          ...         ...
# 45675           other         530R  off-target
# 45676           other         530S  off-target
# 45677           other         530T  off-target
# 45678           other         530V  off-target
# 45679           other         530W  off-target
#
# [45680 rows x 9 columns]

# %% [markdown]
# trim to just the mutations targeted by primers from a single library.

# %%
mut_counts = mut_counts_full.loc[(mut_counts_full['library']=='libA_rep1') & 
                                 (mut_counts_full['targeted'] == 'targeted')]

mut_counts.tail()
# Out:
#          library             sample mutation  mut_count  mutation_type  site  \
# 3432   libA_rep1  barcoded variants    I233D          1  nonsynonymous   233
# 3572   libA_rep1  barcoded variants    S133G          1  nonsynonymous   133
# 3573   libA_rep1  barcoded variants    S133V          1  nonsynonymous   133
# 3608   libA_rep1  barcoded variants     T49G          1  nonsynonymous    49
# 10295  libA_rep1  barcoded variants     T31L          0  nonsynonymous    31
#
#       epitope stripped_mut  targeted
# 3432    other         233D  targeted
# 3572    other         133G  targeted
# 3573    other         133V  targeted
# 3608    other          49G  targeted
# 10295   other          31L  targeted

# %% [markdown]
# pull just the column defining site/AA, and the column describing type of mutation. Convert to df needed for analysis.

# %%
aggregated_muts = mut_counts[['stripped_mut', 'epitope']]

# split 'stripped_mut' into site and aa columns
aggregated_muts[['site', 'amino_acid']] = aggregated_muts['stripped_mut'].str.extract('(\d+\.?\d+)([a-zA-Z*]+)',
                                                                                      expand=True)

# convert 'epitope' column into appropriate mutation type labels
mutation_type_conversion = {'paired_epitope':'paired_epitope_mutation', 
                            'epitope':'epitope_mutation',
                            'other':'viable_mutation'}

aggregated_muts['mutation_type'] = aggregated_muts['epitope'].map(mutation_type_conversion)

# drop unneeded columns
aggregated_muts = aggregated_muts.drop(['stripped_mut', 'epitope'], axis=1)

# sort in site order
aggregated_muts['site']=aggregated_muts['site'].astype(int)
aggregated_muts = aggregated_muts.sort_values(by='site').reset_index(drop=True)

aggregated_muts
# Out:
# /fh/fast/bloom_j/software/miniconda3/envs/BloomLab/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /tmp/ipykernel_40302/2702391872.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aggregated_muts['mutation_type'] = aggregated_muts['epitope'].map(mutation_type_conversion)
#       site amino_acid    mutation_type
# 0       22          Y  viable_mutation
# 1       22          R  viable_mutation
# 2       22          G  viable_mutation
# 3       22          E  viable_mutation
# 4       22          A  viable_mutation
# ...    ...        ...              ...
# 2684   523          N  viable_mutation
# 2685   523          R  viable_mutation
# 2686   523          C  viable_mutation
# 2687   523          S  viable_mutation
# 2688   523          I  viable_mutation
#
# [2689 rows x 3 columns]

# %%
aggregated_muts.to_csv('aggregated_mutations.csv', index=False)
